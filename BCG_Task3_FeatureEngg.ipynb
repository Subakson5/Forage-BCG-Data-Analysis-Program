# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import pandas as pd
import seaborn as sns
import datetime
import pickle

# %%
# list of dates
date_list = ['date_activ','date_end','date_first_activ','date_modif_prod','date_renewal']

# Read in dataset
df_train = pd.read_csv("G:\\virtual experience\\BCG\\ml_case_training_data(1).csv", parse_dates=date_list)
df_hist = pd.read_csv("G:\\virtual experience\\BCG\\ml_case_training_hist_data(1).csv", parse_dates=['price_date'])
df_out = pd.read_csv("G:\\virtual experience\\BCG\\ml_case_training_output(1).csv")

# %%
df_train.head()
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3  764c75f661154dac3a6c254cd082ea7d                               NaN
# 4  bba03439a292a1e166f80264c16191cb                               NaN
#
#    campaign_disc_ele                     channel_sales  cons_12m  \
# 0                NaN  lmkebamcaaclubfxadlmueccxoimlema    309275
# 1                NaN  foosdfpfkusacimwkcsosbicdxkicaua         0
# 2                NaN                               NaN      4660
# 3                NaN  foosdfpfkusacimwkcsosbicdxkicaua       544
# 4                NaN  lmkebamcaaclubfxadlmueccxoimlema      1584
#
#    cons_gas_12m  cons_last_month date_activ   date_end date_first_activ  ...  \
# ...

# %%
df_hist.head()
# Out:
#                                  id price_date  price_p1_var  price_p2_var  \
# 0  038af19179925da21a25619c5a24b745 2015-01-01      0.151367           0.0
# 1  038af19179925da21a25619c5a24b745 2015-02-01      0.151367           0.0
# 2  038af19179925da21a25619c5a24b745 2015-03-01      0.151367           0.0
# 3  038af19179925da21a25619c5a24b745 2015-04-01      0.149626           0.0
# 4  038af19179925da21a25619c5a24b745 2015-05-01      0.149626           0.0
#
#    price_p3_var  price_p1_fix  price_p2_fix  price_p3_fix
# 0           0.0     44.266931           0.0           0.0
# 1           0.0     44.266931           0.0           0.0
# 2           0.0     44.266931           0.0           0.0
# 3           0.0     44.266931           0.0           0.0
# 4           0.0     44.266931           0.0           0.0

# %% [markdown]
# # Trying to do some feature engineering

# %% [markdown]
# Tenure of customer activity:
# Ending date - Active date

# %%
df_train.isnull().sum()
# Out:
# id                              0
# activity_new                 9545
# campaign_disc_ele           16096
# channel_sales                4218
# cons_12m                        0
# cons_gas_12m                    0
# cons_last_month                 0
# date_activ                      0
# date_end                        2
# date_first_activ            12588
# date_modif_prod               157
# date_renewal                   40
# forecast_base_bill_ele      12588
# forecast_base_bill_year     12588
# forecast_bill_12m           12588
# forecast_cons               12588
# forecast_cons_12m               0
# forecast_cons_year              0
# forecast_discount_energy      126
# forecast_meter_rent_12m         0
# forecast_price_energy_p1      126
# forecast_price_energy_p2      126
# forecast_price_pow_p1         126
# has_gas                         0
# imp_cons                        0
# margin_gross_pow_ele           13
# margin_net_pow_ele             13
# ...

# %%
df_train.loc[df_train["date_end"].isnull(),"date_end"] = df_train["date_end"].value_counts().index[0]

# %%
df_train["tenure"] = ((df_train["date_end"]-df_train["date_activ"])/ np.timedelta64(1, "Y")).astype(int)

# %%
df_train_merged = df_train.merge(right=df_out,on=['id'])
df_train_merged.head()
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3  764c75f661154dac3a6c254cd082ea7d                               NaN
# 4  bba03439a292a1e166f80264c16191cb                               NaN
#
#    campaign_disc_ele                     channel_sales  cons_12m  \
# 0                NaN  lmkebamcaaclubfxadlmueccxoimlema    309275
# 1                NaN  foosdfpfkusacimwkcsosbicdxkicaua         0
# 2                NaN                               NaN      4660
# 3                NaN  foosdfpfkusacimwkcsosbicdxkicaua       544
# 4                NaN  lmkebamcaaclubfxadlmueccxoimlema      1584
#
#    cons_gas_12m  cons_last_month date_activ   date_end date_first_activ  ...  \
# ...

# %%
tenure = df_train_merged[["tenure", "churn", "id"]].groupby(["tenure", "churn"])["id"].count().unstack(level=1)
tenure_percentage = (tenure.div(tenure.sum(axis=1), axis=0)*100)

# %%
tenure.plot(kind="bar",
            figsize=(18,10),
            title= "Tenure of Contract")
# Rename legend
plt.legend(["Stayed", "Left"])
# Labels
plt.ylabel("No. of companies")
plt.xlabel("No. of years")
plt.show()

# %% [markdown]
# Obseravtion:
# 1) Churn rate is low for less than 2 years and for greater than 8 years, meaning churn occurs at either recent or long tenure.
# 2) Churn rate is higher around 3-7 years of tenure, with highest churn and retention occuring at around 4 years.
